# %%
import turtle
import time
import numpy as np
t=turtle.Turtle()
t.shape('turtle')
t.speed(1)

def Triangulo(x):
    for i in range(3):
        t.rt(120)
        t.forward(x)
    
def Cuadrado(x):
    colr=['orange','green','cyan','blue']
    for i in range(4):
        t.color(colr[i])
        t.forward(x)
        t.rt(90)
def Circulo(x):
    t.penup()
    t.goto(0,200)
    t.pendown()
    for i in range(360):
        t.forward(x)
        t.rt(1)
        
def Cuadrados(x):
    for i in range(4):
        t.forward(x*3)
        for k in range(3):
            t.rt(90)            
            t.forward(x)     
            
def Espiral(x):
    ang=np.linspace(0,360,1000)
    for i in range(len(ang)):
        t.rt(ang[i])        
        t.forward(x)

def Casa(a,b):
    t.penup()
    t.goto(a/5,0)
    t.pendown()
    t.rt(90)
    t.forward(a/10)
    for i in range(3):
        t.lt(90)
        t.forward(a/5)
    t.lt(90)
    t.forward(a/10)
    t.penup()
    t.backward(a/10 + b/3)
    t.pendown()
    t.lt(90)
    t.forward(2*a/5)
    for i in range(3):
        t.lt(120)
        t.forward(a)
    t.rt(90)
    t.forward(b)
    t.rt(90)
    t.forward(3*a/5)
    t.rt(90)
    t.forward(b/3)
    t.rt(90)
    t.forward(a/5)
    t.rt(90)
    t.forward(b/3)
    t.rt(90)
    t.forward(3*a/5)
    t.rt(90)
    t.forward(b)
    t.rt(90)
    t.forward(2*a/5)
    t.rt(90)
    t.penup()
    t.forward(b/3)
    t.pendown()
    for i in range(4):
        t.forward(a/5)
        t.rt(90)

# %%
Triangulo(100)
turtle.mainloop()

# %%
Cuadrado(100)
turtle.mainloop()

# %%
Circulo(3)
turtle.mainloop()

# %%
Cuadrados(50)
turtle.mainloop()

# %%
Espiral(10)
turtle.mainloop()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-efc635005d9a> in <module>
# ----> 1 Espiral(10)
#       2 turtle.mainloop()
#
# <ipython-input-1-ac618a13986b> in Espiral(x)
#      35     ang=np.linspace(0,360,1000)
#      36     for i in range(len(ang)):
# ---> 37         t.rt(ang[i])
#      38         t.forward(x)
#      39
#
# ~\Documents\Anaconda\lib\turtle.py in right(self, angle)
#    1677         337.0
#    1678         """
# -> 1679         self._rotate(-angle)
#    1680
#    1681     def left(self, angle):
#
# ~\Documents\Anaconda\lib\turtle.py in _rotate(self, angle)
#    3275             for _ in range(steps):
#    3276                 self._orient = self._orient.rotate(delta)
# -> 3277                 self._update()
#    3278         self._orient = neworient
#    3279         self._update()
#
# ~\Documents\Anaconda\lib\turtle.py in _update(self)
# ...

# %%
Casa(200,200)
turtle.mainloop()
